# %% [markdown]
# # Student GLM: Define events
# Natalia Vélez, April 2022

# %%
# %matplotlib inline

import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import entropy, spearmanr
from ast import literal_eval
from os.path import join as opj

sys.path.append('..')
from utils import gsearch, str_extract, int_extract

sns.set_style('white')
sns.set_context('talk')

# %% [markdown]
# Load student data:

# %%
student_df = (
    pd.read_csv('outputs/student_behavior.csv')
    .drop(columns=['order'])
    .rename(columns={'num_hint': 'student_idx'})
)
student_df['bets'] = student_df.bets.apply(literal_eval)
student_df.head()
# Out:
#    time_elapsed teacher  problem  num_trial  student_idx             bets  \
# 0        181304  sub-04     34.0        0.0          0.0  [0, 35, 41, 48]
# 1        192911  sub-04     34.0        0.0          1.0   [0, 50, 49, 0]
# 2        203582  sub-04     34.0        0.0          2.0   [0, 0, 100, 0]
# 3        223655  sub-27     15.0        1.0          0.0  [0, 52, 50, 48]
# 4        232054  sub-27     15.0        1.0          1.0   [0, 52, 50, 0]
#
#       bonus         worker            batch
# 0  0.013777  ARI1EMAHUA9PO  2022-02-02-1303
# 1  0.020623  ARI1EMAHUA9PO  2022-02-02-1303
# 2  0.041667  ARI1EMAHUA9PO  2022-02-02-1303
# 3  0.014444  ARI1EMAHUA9PO  2022-02-02-1303
# 4  0.021242  ARI1EMAHUA9PO  2022-02-02-1303

# %% [markdown]
# Find original behavioral data:

# %%
data_dir = '/n/gershman_ncf/Lab/natalia_teaching/'
original_files = gsearch(data_dir, 'behavioral', '*.json')
original_files = [f for f in original_files if 'run-practice' not in f] # trim out practice runs
original_files.sort()

print(f'{len(original_files)} behavioral files found')
print(*original_files[:10], sep='\n')
print('...')
# Out:
# 299 behavioral files found
# /n/gershman_ncf/Lab/natalia_teaching/behavioral/sub-01_task-teaching_run-01_behavioral_1628798255.json
# /n/gershman_ncf/Lab/natalia_teaching/behavioral/sub-01_task-teaching_run-02_behavioral_1628798680.json
# /n/gershman_ncf/Lab/natalia_teaching/behavioral/sub-01_task-teaching_run-03_behavioral_1628799162.json
# /n/gershman_ncf/Lab/natalia_teaching/behavioral/sub-01_task-teaching_run-04_behavioral_1628800012.json
# /n/gershman_ncf/Lab/natalia_teaching/behavioral/sub-01_task-teaching_run-05_behavioral_1628800423.json
# /n/gershman_ncf/Lab/natalia_teaching/behavioral/sub-01_task-teaching_run-06_behavioral_1628800796.json
# /n/gershman_ncf/Lab/natalia_teaching/behavioral/sub-01_task-teaching_run-07_behavioral_1628801177.json
# /n/gershman_ncf/Lab/natalia_teaching/behavioral/sub-01_task-teaching_run-08_behavioral_1628801584.json
# /n/gershman_ncf/Lab/natalia_teaching/behavioral/sub-01_task-teaching_run-09_behavioral_1628802076.json
# /n/gershman_ncf/Lab/natalia_teaching/behavioral/sub-01_task-teaching_run-10_behavioral_1628802432.json
# ...

# %% [markdown]
# Load teacher data:

# %%
teach_df = (
    pd.read_csv('../2_behavioral/outputs/teaching_behavior.csv')
    .rename(columns={'ex_idx': 'num_hint', 'subject': 'teacher', 'rating': 'teacher_rating'})
)

# data clean-up: line up student and teacher trial indices
teach_df['teacher'] = teach_df.teacher.apply(lambda x: f'sub-{x:02}')
teach_df['hint_provided'] = ~pd.isna(teach_df.example)
teach_df['hint_cumsum'] = teach_df.groupby(['teacher', 'problem'])['hint_provided'].cumsum() - 1
teach_df['student_idx'] = np.where(teach_df.hint_provided, teach_df.hint_cumsum, np.nan)

teach_df.head()
# Out:
#   teacher  run  block_idx  num_hint first_movement   start   onset  problem  \
# 0  sub-01    1          0         0         [0, 1]  [0, 0]   30.00       22
# 1  sub-01    1          0         1         [0, 1]  [0, 0]   45.35       22
# 2  sub-01    1          0         2         [0, 1]  [0, 0]   59.35       22
# 3  sub-01    1          1         0         [0, 4]  [0, 5]  104.05       18
# 4  sub-01    1          1         1         [0, 4]  [0, 5]  118.45       18
#
#                   order example  teacher_rating  hint_provided  hint_cumsum  \
# 0  ['C', 'B', 'D', 'A']  [1, 2]             1.0           True            0
# 1  ['C', 'B', 'D', 'A']  [4, 3]             2.0           True            1
# 2  ['C', 'B', 'D', 'A']     NaN             2.0          False            1
# 3  ['D', 'B', 'C', 'A']  [0, 3]             0.0           True            0
# 4  ['D', 'B', 'C', 'A']  [5, 2]             NaN           True            1
#
#    student_idx
# 0          0.0
# 1          1.0
# 2          NaN
# 3          0.0
# 4          1.0

# %% [markdown]
# Get matching indices

# %%
matching_indices = (
    teach_df
    [['teacher', 'problem', 'student_idx', 'num_hint']]
    .rename(columns={'num_hint': 'ex_idx'})
)

student_df = (
    student_df
    .merge(matching_indices)
    .sort_values(by=['worker', 'num_trial', 'student_idx'])
    .reset_index(drop=True)
)

# %% [markdown]
# Load problem orders:

# %%
problem_orders = (
    teach_df
    [['teacher', 'problem', 'run', 'block_idx', 'order']]
    .drop_duplicates()
)
problem_orders['order'] = problem_orders.order.apply(literal_eval)
problem_orders.head()
# Out:
#    teacher  problem  run  block_idx         order
# 0   sub-01       22    1          0  [C, B, D, A]
# 3   sub-01       18    1          1  [D, B, C, A]
# 6   sub-01        1    1          2  [A, D, C, B]
# 9   sub-01       16    1          3  [B, C, A, D]
# 12  sub-01       20    2          0  [D, C, A, B]

# %% [markdown]
# ## Measure empirical pTrue, KL

# %% [markdown]
# Data wrangling:

# %%
def sort_bets(row):
    beliefs_sorted = [bet for h, bet in sorted(zip(row.order, row.bets))]
    return beliefs_sorted

# Reorder student bets to align with model-predicted belief distribution:
student_belief = student_df.copy().merge(problem_orders, on =['teacher', 'problem'], how='left')
student_belief['bets_sorted'] = student_belief.apply(sort_bets, axis=1)
student_belief['pTrue'] = student_belief.bets_sorted.apply(lambda b: b[0]/sum(b))
student_belief['num_hint'] = (student_belief['student_idx']+1).astype(int)

# Measure KL divergence
kl_list = []
for name,group in student_belief.groupby(['worker', 'problem']):
    prior = np.ones(4)/4 # start with a uniform prior
    
    for _, row in group.iterrows():
        bets = np.array(row.bets_sorted) + 0.0001 # small adjustment to fix divide-by-0 error
        belief = bets/np.sum(bets)
        kl = entropy(prior, belief)
        
        prior = belief # carry over belief dist from prior trial
        kl_list.append(kl)
        
student_belief['KL'] = kl_list

print(student_belief.shape)
student_belief.tail(25)
# Out:
# (16150, 17)
#        time_elapsed teacher  problem  num_trial  student_idx  \
# 16125       1165930  sub-20     12.0       31.0          0.0
# 16126       1176602  sub-20     12.0       31.0          1.0
# 16127       1182202  sub-20     12.0       31.0          2.0
# 16128       1194436  sub-01     25.0       32.0          0.0
# 16129       1202023  sub-01     25.0       32.0          1.0
# 16130       1214435  sub-23      6.0       33.0          0.0
# 16131       1217395  sub-23      6.0       33.0          1.0
# 16132       1222898  sub-23      6.0       33.0          2.0
# 16133       1245622  sub-19     14.0       34.0          0.0
# 16134       1253811  sub-19     14.0       34.0          1.0
# 16135       1262732  sub-19     14.0       34.0          2.0
# 16136       1273175  sub-18      5.0       35.0          0.0
# 16137       1278692  sub-18      5.0       35.0          1.0
# 16138       1281311  sub-18      5.0       35.0          2.0
# 16139       1300331  sub-11     37.0       36.0          0.0
# 16140       1331593  sub-11     37.0       36.0          1.0
# 16141       1348681  sub-10     33.0       37.0          0.0
# 16142       1356434  sub-10     33.0       37.0          1.0
# 16143       1362021  sub-10     33.0       37.0          2.0
# 16144       1374562  sub-30     34.0       38.0          0.0
# 16145       1382938  sub-30     34.0       38.0          1.0
# 16146       1385821  sub-30     34.0       38.0          2.0
# 16147       1398967  sub-05     36.0       39.0          0.0
# 16148       1405439  sub-05     36.0       39.0          1.0
# 16149       1412169  sub-05     36.0       39.0          2.0
#
#                    bets     bonus         worker            batch  ex_idx  \
# 16125  [25, 25, 25, 23]  0.010629  AZNIEFUIVB2H0  2022-02-16-1639       0
# 16126  [13, 55, 13, 23]  0.022035  AZNIEFUIVB2H0  2022-02-16-1639       1
# 16127  [13, 79, 13, 23]  0.025716  AZNIEFUIVB2H0  2022-02-16-1639       2
# 16128  [25, 25, 30, 25]  0.014881  AZNIEFUIVB2H0  2022-02-16-1639       0
# 16129  [25, 25, 30, 27]  0.015771  AZNIEFUIVB2H0  2022-02-16-1639       2
# 16130    [0, 60, 62, 0]  0.020492  AZNIEFUIVB2H0  2022-02-16-1639       0
# 16131    [0, 63, 62, 0]  0.021000  AZNIEFUIVB2H0  2022-02-16-1639       1
# 16132    [0, 76, 62, 0]  0.022947  AZNIEFUIVB2H0  2022-02-16-1639       2
# 16133  [34, 25, 25, 25]  0.012997  AZNIEFUIVB2H0  2022-02-16-1639       0
# 16134  [21, 61, 25, 25]  0.006629  AZNIEFUIVB2H0  2022-02-16-1639       1
# 16135    [21, 61, 0, 0]  0.010671  AZNIEFUIVB2H0  2022-02-16-1639       2
# 16136    [52, 0, 54, 0]  0.020440  AZNIEFUIVB2H0  2022-02-16-1639       0
# 16137    [78, 0, 31, 0]  0.029817  AZNIEFUIVB2H0  2022-02-16-1639       1
# 16138    [90, 0, 31, 0]  0.030992  AZNIEFUIVB2H0  2022-02-16-1639       2
# 16139   [25, 25, 0, 25]  0.020833  AZNIEFUIVB2H0  2022-02-16-1639       0
# 16140     [0, 80, 0, 0]  0.062500  AZNIEFUIVB2H0  2022-02-16-1639       1
# 16141  [25, 25, 31, 25]  0.009827  AZNIEFUIVB2H0  2022-02-16-1639       0
# 16142   [25, 10, 31, 8]  0.014077  AZNIEFUIVB2H0  2022-02-16-1639       1
# 16143   [68, 10, 53, 8]  0.020384  AZNIEFUIVB2H0  2022-02-16-1639       2
# 16144    [0, 61, 0, 75]  0.022978  AZNIEFUIVB2H0  2022-02-16-1639       0
# 16145    [0, 0, 0, 100]  0.041667  AZNIEFUIVB2H0  2022-02-16-1639       1
# 16146    [0, 0, 0, 100]  0.041667  AZNIEFUIVB2H0  2022-02-16-1639       2
# 16147   [0, 58, 55, 64]  0.013653  AZNIEFUIVB2H0  2022-02-16-1639       0
# 16148   [0, 82, 42, 64]  0.018174  AZNIEFUIVB2H0  2022-02-16-1639       1
# 16149  [0, 100, 31, 37]  0.024802  AZNIEFUIVB2H0  2022-02-16-1639       2
#
#        run  block_idx         order       bets_sorted     pTrue  num_hint  \
# 16125    8          1  [B, A, D, C]  [25, 25, 23, 25]  0.255102         1
# 16126    8          1  [B, A, D, C]  [55, 13, 23, 13]  0.528846         2
# 16127    8          1  [B, A, D, C]  [79, 13, 23, 13]  0.617188         3
# 16128    7          3  [B, D, C, A]  [25, 25, 30, 25]  0.238095         1
# 16129    7          3  [B, D, C, A]  [27, 25, 30, 25]  0.252336         2
# 16130    5          1  [D, A, C, B]    [60, 0, 62, 0]  0.491803         1
# 16131    5          1  [D, A, C, B]    [63, 0, 62, 0]  0.504000         2
# 16132    5          1  [D, A, C, B]    [76, 0, 62, 0]  0.550725         3
# 16133    4          3  [A, D, C, B]  [34, 25, 25, 25]  0.311927         1
# 16134    4          3  [A, D, C, B]  [21, 25, 25, 61]  0.159091         2
# 16135    4          3  [A, D, C, B]    [21, 0, 0, 61]  0.256098         3
# 16136    4          1  [A, B, C, D]    [52, 0, 54, 0]  0.490566         1
# 16137    4          1  [A, B, C, D]    [78, 0, 31, 0]  0.715596         2
# 16138    4          1  [A, B, C, D]    [90, 0, 31, 0]  0.743802         3
# 16139   10          2  [D, A, B, C]   [25, 0, 25, 25]  0.333333         1
# 16140   10          2  [D, A, B, C]     [80, 0, 0, 0]  1.000000         2
# 16141    5          1  [A, B, C, D]  [25, 25, 31, 25]  0.235849         1
# 16142    5          1  [A, B, C, D]   [25, 10, 31, 8]  0.337838         2
# 16143    5          1  [A, B, C, D]   [68, 10, 53, 8]  0.489209         3
# 16144    9          1  [C, B, D, A]    [75, 61, 0, 0]  0.551471         1
# 16145    9          1  [C, B, D, A]    [100, 0, 0, 0]  1.000000         2
# 16146    9          1  [C, B, D, A]    [100, 0, 0, 0]  1.000000         3
# 16147    9          2  [D, A, B, C]   [58, 55, 64, 0]  0.327684         1
# 16148    9          2  [D, A, B, C]   [82, 42, 64, 0]  0.436170         2
# 16149    9          2  [D, A, B, C]  [100, 31, 37, 0]  0.595238         3
#
#              KL
# 16125  5.998858
# 16126  2.819624
# 16127  4.003466
# 16128  2.975051
# 16129  2.404362
# 16130  0.000091
# 16131  0.004491
# 16132  0.125465
# 16133  0.067689
# 16134  6.024442
# 16135  5.508818
# 16136  0.000000
# 16137  5.893000
# 16138  6.544671
# 16139  0.000000
# 16140  3.035777
# 16141  0.030617
# 16142  0.055349
# 16143  2.819624
# 16144  7.962958
# 16145  2.838582
# 16146  3.740737
# 16147  0.014391
# 16148  3.043601
# 16149  0.000038

# %% [markdown]
# Plot empirical pTrue, KL

# %%
fig,axes = plt.subplots(1,2,figsize=(8,4))

sns.pointplot(data=student_belief, x='num_hint', y='pTrue', ax=axes[0])
axes[0].set(xlabel='Hints presented', ylabel='Belief in correct answer')

sns.pointplot(data=student_belief, x='num_hint', y='KL', ax=axes[1])
axes[1].set(xlabel='Hints presented', ylabel='Belief update')

fig.tight_layout()

# %% [markdown]
# Plot correlations between parametric regressors

# %% [markdown]
# ## Comparison to model-based measures

# %% [markdown]
# Load model predictions:

# %%
model_df = (
    pd.read_csv('../2_behavioral/outputs/model_regressor_values.csv')
    .melt(id_vars = ['subject', 'problem', 'run', 'block_idx', 'ex_idx'], value_vars=['pTrue', 'KL'])
    .rename(columns={'subject': 'teacher', 'block_idx': 'block_no'})
)
model_df['teacher'] = model_df.teacher.apply(lambda x: f'sub-{x:02}')
model_df['source'] = 'model'
model_df.head()
# Out:
#   teacher  problem  run  block_no  ex_idx variable     value source
# 0  sub-01       22    1         0       0    pTrue -0.126543  model
# 1  sub-01       22    1         0       1    pTrue  0.040123  model
# 2  sub-01       18    1         1       0    pTrue  0.040123  model
# 3  sub-01       18    1         1       1    pTrue  0.040123  model
# 4  sub-01       18    1         1       2    pTrue  0.040123  model

# %% [markdown]
# Reshape human judgments:

# %%
# data-wrangling
human_df = (
    student_belief
    .groupby(['teacher', 'problem', 'run', 'block_idx', 'ex_idx'])
    .agg({'pTrue': 'mean', 'KL': 'mean'})
    .reset_index()
    .melt(id_vars = ['teacher', 'problem', 'run', 'block_idx', 'ex_idx'], value_vars=['pTrue', 'KL'])
)
human_df['problem'] = human_df['problem'].astype(int)
human_df['source'] = 'human'

# mean-center parametric regressors
means = human_df.groupby(['teacher', 'variable']).value.transform('mean')
human_df['value'] = human_df['value'] - means

human_df.head()
# Out:
#   teacher  problem  run  block_idx  ex_idx variable     value source
# 0  sub-01        0    7          2       0    pTrue -0.022550  human
# 1  sub-01        0    7          2       1    pTrue  0.118111  human
# 2  sub-01        0    7          2       2    pTrue  0.329977  human
# 3  sub-01        1    1          2       0    pTrue -0.244056  human
# 4  sub-01        1    1          2       1    pTrue  0.398331  human

# %% [markdown]
# Put it all together:

# %%
human_vs_model = (
    pd.concat([human_df, model_df])
    .pivot(index=['teacher', 'problem', 'ex_idx', 'variable'], columns='source', values='value')
    .reset_index()
    .dropna(subset=['human', 'model']) 
)
print(human_vs_model.shape)
human_vs_model.head()
# Out:
# (6410, 6)
# source teacher  problem  ex_idx variable     human     model
# 0       sub-01        0       0       KL -0.885856  2.341827
# 1       sub-01        0       0    pTrue -0.022550  0.040123
# 2       sub-01        0       1       KL -0.200151 -1.223922
# 3       sub-01        0       1    pTrue  0.118111  0.040123
# 4       sub-01        0       2       KL -0.404594  2.687469

# %% [markdown]
# Comparison between empirical and model-predicted pTrue:

# %%
ptrue_df = human_vs_model[human_vs_model.variable == 'pTrue']
print(spearmanr(ptrue_df.human, ptrue_df.model))
g = sns.jointplot(data=ptrue_df, x='human', y='model', kind='hex')
g.fig.suptitle('Posterior belief in correct answer')
g.fig.tight_layout()
g.set_axis_labels('Student responses', 'Model predictions')
plt.savefig('plots/student_vs_model_pTrue.png')
# Out:
# SpearmanrResult(correlation=0.7803666761407536, pvalue=0.0)

# %%
kl_df = human_vs_model[(human_vs_model.variable == 'KL')]
print(spearmanr(kl_df.human, kl_df.model))

g = sns.jointplot(data=kl_df, x='human', y='model', kind='hex')
g.fig.suptitle('Belief update')
g.fig.tight_layout()
g.set_axis_labels('Student responses', 'Model predictions')
plt.savefig('plots/student_vs_model_KL.png')
# Out:
# SpearmanrResult(correlation=0.05571119536980578, pvalue=0.0016039776371710333)

# %% [markdown]
# ## Prepare parametric regressors for univariate analyses

# %% [markdown]
# Find event files:

# %%
data_dir = '../../BIDS_data'
event_files = gsearch(data_dir, 'sub-*', 'func', '*task-teaching*events.tsv')
event_files.sort()

print(f'Found {len(event_files)} behavioral files')
print(*event_files[:10], sep='\n')
print('...')
# Out:
# Found 299 behavioral files
# ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-01_events.tsv
# ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-02_events.tsv
# ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-03_events.tsv
# ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-04_events.tsv
# ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-05_events.tsv
# ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-06_events.tsv
# ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-07_events.tsv
# ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-08_events.tsv
# ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-09_events.tsv
# ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-10_events.tsv
# ...

# %% [markdown]
# Valid participants:

# %%
valid_participants = np.loadtxt('../1_preprocessing/outputs/valid_participants.txt')
valid_participants = ['sub-%02d' % s for s in valid_participants]
print(valid_participants)
# Out:
# ['sub-01', 'sub-02', 'sub-04', 'sub-05', 'sub-06', 'sub-07', 'sub-08', 'sub-09', 'sub-10', 'sub-11', 'sub-12', 'sub-13', 'sub-14', 'sub-15', 'sub-16', 'sub-18', 'sub-19', 'sub-20', 'sub-21', 'sub-22', 'sub-23', 'sub-24', 'sub-25', 'sub-26', 'sub-27', 'sub-28', 'sub-29', 'sub-30']

# %% [markdown]
# Wrangle empirical regressors:

# %%
human_reg = (
    human_df
    .rename(columns={'teacher': 'subject', 'block_idx': 'block_no', 'ex_idx': 'trial_no', 'problem': 'stimuli'})
    .sort_values(by=['subject', 'run', 'block_no', 'trial_no'])
    .reset_index(drop=True)
    .drop(columns=['source'])
    .pivot(index=['subject', 'run', 'block_no', 'trial_no', 'stimuli'], columns='variable', values='value')
    .reset_index()
)
print(human_reg.shape)
human_reg.head(10)
# Out:
# (3205, 7)
# variable subject  run  block_no  trial_no  stimuli        KL     pTrue
# 0         sub-01    1         0         0       22  0.754749 -0.211405
# 1         sub-01    1         0         1       22  0.248322 -0.069094
# 2         sub-01    1         1         0       18  1.273673 -0.122948
# 3         sub-01    1         1         1       18 -2.006561 -0.158416
# 4         sub-01    1         1         2       18  1.693224 -0.099848
# 5         sub-01    1         2         0        1  2.506834 -0.244056
# 6         sub-01    1         2         1        1  0.434128  0.398331
# 7         sub-01    1         2         2        1 -1.188491  0.498331
# 8         sub-01    1         3         1       16 -1.355016 -0.148216
# 9         sub-01    1         3         2       16  2.745766 -0.165959

# %% [markdown]
# Check: Correlations between empirical regressors

# %%
corr_list = []
for sub,group in human_reg.groupby('subject'):
    res = spearmanr(group.pTrue, group.KL)
    corr_list.append((sub, res.correlation))
    
corr_df = pd.DataFrame(corr_list, columns=['subject', 'correlation'])
print(corr_df.shape)
print(corr_df.correlation.mean())
corr_df.head()
# Out:
# (28, 2)
# -0.004715314213142289
#   subject  correlation
# 0  sub-01     0.092732
# 1  sub-02     0.022082
# 2  sub-04     0.248490
# 3  sub-05    -0.022482
# 4  sub-06    -0.176109

# %%
fig,ax=plt.subplots(figsize=(5,4))
sns.histplot(data=corr_df,x='correlation',ax=ax)
ax.set(xlim=(-1,1), xlabel=r'Correlation ($r$)', ylabel='')
ax.axvline(x=0, linestyle='--', color='#aaa')

# %%
spearmanr(group.pTrue, group.KL)
# Out:
# SpearmanrResult(correlation=-0.066380301208212, pvalue=0.47131341581792197)

# %% [markdown]
# Helper function: Prepare event files

# %%
def make_empirical_reg(f):
    
    # get event data
    event_df = pd.read_csv(f, sep='\t')

    # get regressors
    sub = str_extract('sub-[0-9]{2}', f)
    run = int_extract('(?<=run-)[0-9]{2}', f)
    run_reg = human_reg[(human_reg.subject == sub) & (human_reg.run == run)]
    run_reg = run_reg[['block_no', 'trial_no', 'pTrue', 'KL']]

    # split "show" trials based on whether a hint was ever actually presented to students
    choose_trials = event_df[event_df.trial_type == 'choose'].merge(run_reg, on=['block_no', 'trial_no'], how='left')
    missed_trial = pd.isnull(choose_trials.response) | pd.isnull(choose_trials.pTrue)
    show_renamed = np.where(missed_trial, 'show_missed', 'show_new')
    event_df.loc[event_df.trial_type == 'show', 'trial_type'] = show_renamed

    # merge with event files
    show_trials = (
        event_df
        [event_df.trial_type == 'show_new']
        .copy()
        .drop(columns='trial_type')
        .merge(run_reg, on=['block_no', 'trial_no'], how='left')
        .melt(id_vars=['onset', 'duration', 'block_no', 'trial_no', 'stimuli', 'stimuli_order', 'response', 'response_time'],
              value_vars=['pTrue', 'KL'], var_name='trial_type', value_name='value')
    )

    # put everything together
    empirical_events = pd.concat([event_df, show_trials])
    empirical_events = (
        empirical_events
        .assign(trial_type=empirical_events.trial_type.astype('category').cat.reorder_categories(event_df.trial_type.unique().tolist() + ['pTrue', 'KL']))
        .sort_values(by=['onset', 'duration', 'trial_type'])
        [['onset', 'duration', 'trial_type', 'block_no', 'trial_no', 'value']]
        .reset_index(drop=True)
    )

    return empirical_events

# %% [markdown]
# Main loop: Assemble event files

# %%
out_dir = '../../BIDS_data/derivatives/model_events'
os.makedirs(out_dir, exist_ok=True)

for f in event_files:
    sub = str_extract('sub-[0-9]{2}', f)
    run = str_extract('run-[0-9]{2}', f)
    out_f = opj(out_dir, sub, 'func', f'{sub}_task-teaching_{run}_model-empirical_events.tsv')
    
    if sub in valid_participants:
        print(f'Loading file: {f}')
        out_df = make_empirical_reg(f)
        
        print(f'Saving to: {out_f}\n')
        os.makedirs(opj(out_dir, sub, 'func'), exist_ok=True)
        out_df.to_csv(out_f, sep='\t', index=False, na_rep='n/a')
# Out:
# Loading file: ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-01/func/sub-01_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-01/func/sub-01_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-01/func/sub-01_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-01/func/sub-01_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-01/func/sub-01_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-01/func/sub-01_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-01/func/sub-01_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-01/func/sub-01_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-01/func/sub-01_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-01/func/sub-01_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-01/func/sub-01_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-02/func/sub-02_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-02/func/sub-02_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-02/func/sub-02_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-02/func/sub-02_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-02/func/sub-02_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-02/func/sub-02_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-02/func/sub-02_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-02/func/sub-02_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-02/func/sub-02_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-02/func/sub-02_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-02/func/sub-02_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-02/func/sub-02_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-02/func/sub-02_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-02/func/sub-02_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-02/func/sub-02_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-02/func/sub-02_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-02/func/sub-02_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-02/func/sub-02_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-02/func/sub-02_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-02/func/sub-02_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-04/func/sub-04_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-04/func/sub-04_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-04/func/sub-04_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-04/func/sub-04_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-04/func/sub-04_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-04/func/sub-04_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-04/func/sub-04_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-04/func/sub-04_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-04/func/sub-04_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-04/func/sub-04_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-04/func/sub-04_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-04/func/sub-04_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-04/func/sub-04_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-04/func/sub-04_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-04/func/sub-04_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-04/func/sub-04_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-04/func/sub-04_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-04/func/sub-04_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-04/func/sub-04_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-04/func/sub-04_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-05/func/sub-05_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-05/func/sub-05_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-05/func/sub-05_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-05/func/sub-05_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-05/func/sub-05_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-05/func/sub-05_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-05/func/sub-05_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-05/func/sub-05_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-05/func/sub-05_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-05/func/sub-05_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-05/func/sub-05_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-05/func/sub-05_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-05/func/sub-05_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-05/func/sub-05_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-05/func/sub-05_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-05/func/sub-05_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-05/func/sub-05_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-05/func/sub-05_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-05/func/sub-05_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-05/func/sub-05_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-06/func/sub-06_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-06/func/sub-06_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-06/func/sub-06_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-06/func/sub-06_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-06/func/sub-06_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-06/func/sub-06_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-06/func/sub-06_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-06/func/sub-06_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-06/func/sub-06_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-06/func/sub-06_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-06/func/sub-06_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-06/func/sub-06_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-06/func/sub-06_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-06/func/sub-06_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-06/func/sub-06_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-06/func/sub-06_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-06/func/sub-06_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-06/func/sub-06_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-06/func/sub-06_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-06/func/sub-06_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-07/func/sub-07_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-07/func/sub-07_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-07/func/sub-07_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-07/func/sub-07_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-07/func/sub-07_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-07/func/sub-07_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-07/func/sub-07_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-07/func/sub-07_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-07/func/sub-07_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-07/func/sub-07_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-07/func/sub-07_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-07/func/sub-07_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-07/func/sub-07_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-07/func/sub-07_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-07/func/sub-07_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-07/func/sub-07_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-07/func/sub-07_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-07/func/sub-07_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-07/func/sub-07_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-07/func/sub-07_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-08/func/sub-08_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-08/func/sub-08_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-08/func/sub-08_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-08/func/sub-08_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-08/func/sub-08_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-08/func/sub-08_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-08/func/sub-08_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-08/func/sub-08_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-08/func/sub-08_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-08/func/sub-08_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-08/func/sub-08_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-08/func/sub-08_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-08/func/sub-08_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-08/func/sub-08_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-08/func/sub-08_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-08/func/sub-08_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-08/func/sub-08_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-08/func/sub-08_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-08/func/sub-08_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-08/func/sub-08_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-09/func/sub-09_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-09/func/sub-09_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-09/func/sub-09_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-09/func/sub-09_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-09/func/sub-09_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-09/func/sub-09_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-09/func/sub-09_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-09/func/sub-09_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-09/func/sub-09_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-09/func/sub-09_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-09/func/sub-09_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-09/func/sub-09_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-09/func/sub-09_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-09/func/sub-09_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-09/func/sub-09_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-09/func/sub-09_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-09/func/sub-09_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-09/func/sub-09_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-09/func/sub-09_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-09/func/sub-09_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-10/func/sub-10_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-10/func/sub-10_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-10/func/sub-10_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-10/func/sub-10_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-10/func/sub-10_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-10/func/sub-10_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-10/func/sub-10_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-10/func/sub-10_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-10/func/sub-10_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-10/func/sub-10_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-10/func/sub-10_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-10/func/sub-10_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-10/func/sub-10_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-10/func/sub-10_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-10/func/sub-10_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-10/func/sub-10_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-10/func/sub-10_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-10/func/sub-10_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-10/func/sub-10_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-10/func/sub-10_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-11/func/sub-11_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-11/func/sub-11_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-11/func/sub-11_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-11/func/sub-11_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-11/func/sub-11_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-11/func/sub-11_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-11/func/sub-11_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-11/func/sub-11_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-11/func/sub-11_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-11/func/sub-11_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-11/func/sub-11_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-11/func/sub-11_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-11/func/sub-11_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-11/func/sub-11_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-11/func/sub-11_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-11/func/sub-11_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-11/func/sub-11_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-11/func/sub-11_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-11/func/sub-11_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-11/func/sub-11_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-12/func/sub-12_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-12/func/sub-12_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-12/func/sub-12_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-12/func/sub-12_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-12/func/sub-12_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-12/func/sub-12_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-12/func/sub-12_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-12/func/sub-12_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-12/func/sub-12_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-12/func/sub-12_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-12/func/sub-12_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-12/func/sub-12_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-12/func/sub-12_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-12/func/sub-12_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-12/func/sub-12_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-12/func/sub-12_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-12/func/sub-12_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-12/func/sub-12_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-12/func/sub-12_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-12/func/sub-12_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-13/func/sub-13_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-13/func/sub-13_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-13/func/sub-13_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-13/func/sub-13_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-13/func/sub-13_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-13/func/sub-13_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-13/func/sub-13_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-13/func/sub-13_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-13/func/sub-13_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-13/func/sub-13_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-13/func/sub-13_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-13/func/sub-13_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-13/func/sub-13_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-13/func/sub-13_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-13/func/sub-13_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-13/func/sub-13_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-13/func/sub-13_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-13/func/sub-13_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-13/func/sub-13_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-13/func/sub-13_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-14/func/sub-14_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-14/func/sub-14_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-14/func/sub-14_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-14/func/sub-14_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-14/func/sub-14_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-14/func/sub-14_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-14/func/sub-14_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-14/func/sub-14_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-14/func/sub-14_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-14/func/sub-14_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-14/func/sub-14_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-14/func/sub-14_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-14/func/sub-14_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-14/func/sub-14_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-14/func/sub-14_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-14/func/sub-14_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-14/func/sub-14_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-14/func/sub-14_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-14/func/sub-14_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-14/func/sub-14_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-15/func/sub-15_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-15/func/sub-15_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-15/func/sub-15_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-15/func/sub-15_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-15/func/sub-15_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-15/func/sub-15_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-15/func/sub-15_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-15/func/sub-15_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-15/func/sub-15_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-15/func/sub-15_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-15/func/sub-15_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-15/func/sub-15_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-15/func/sub-15_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-15/func/sub-15_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-15/func/sub-15_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-15/func/sub-15_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-15/func/sub-15_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-15/func/sub-15_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-15/func/sub-15_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-15/func/sub-15_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-16/func/sub-16_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-16/func/sub-16_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-16/func/sub-16_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-16/func/sub-16_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-16/func/sub-16_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-16/func/sub-16_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-16/func/sub-16_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-16/func/sub-16_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-16/func/sub-16_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-16/func/sub-16_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-16/func/sub-16_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-16/func/sub-16_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-16/func/sub-16_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-16/func/sub-16_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-16/func/sub-16_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-16/func/sub-16_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-16/func/sub-16_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-16/func/sub-16_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-16/func/sub-16_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-16/func/sub-16_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-18/func/sub-18_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-18/func/sub-18_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-18/func/sub-18_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-18/func/sub-18_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-18/func/sub-18_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-18/func/sub-18_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-18/func/sub-18_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-18/func/sub-18_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-18/func/sub-18_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-18/func/sub-18_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-18/func/sub-18_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-18/func/sub-18_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-18/func/sub-18_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-18/func/sub-18_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-18/func/sub-18_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-18/func/sub-18_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-18/func/sub-18_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-18/func/sub-18_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-18/func/sub-18_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-18/func/sub-18_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-19/func/sub-19_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-19/func/sub-19_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-19/func/sub-19_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-19/func/sub-19_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-19/func/sub-19_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-19/func/sub-19_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-19/func/sub-19_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-19/func/sub-19_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-19/func/sub-19_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-19/func/sub-19_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-19/func/sub-19_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-19/func/sub-19_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-19/func/sub-19_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-19/func/sub-19_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-19/func/sub-19_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-19/func/sub-19_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-19/func/sub-19_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-19/func/sub-19_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-19/func/sub-19_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-19/func/sub-19_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-20/func/sub-20_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-20/func/sub-20_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-20/func/sub-20_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-20/func/sub-20_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-20/func/sub-20_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-20/func/sub-20_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-20/func/sub-20_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-20/func/sub-20_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-20/func/sub-20_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-20/func/sub-20_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-20/func/sub-20_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-20/func/sub-20_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-20/func/sub-20_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-20/func/sub-20_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-20/func/sub-20_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-20/func/sub-20_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-20/func/sub-20_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-20/func/sub-20_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-20/func/sub-20_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-20/func/sub-20_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-21/func/sub-21_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-21/func/sub-21_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-21/func/sub-21_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-21/func/sub-21_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-21/func/sub-21_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-21/func/sub-21_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-21/func/sub-21_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-21/func/sub-21_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-21/func/sub-21_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-21/func/sub-21_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-21/func/sub-21_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-21/func/sub-21_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-21/func/sub-21_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-21/func/sub-21_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-21/func/sub-21_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-21/func/sub-21_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-21/func/sub-21_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-21/func/sub-21_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-21/func/sub-21_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-21/func/sub-21_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-22/func/sub-22_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-22/func/sub-22_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-22/func/sub-22_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-22/func/sub-22_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-22/func/sub-22_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-22/func/sub-22_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-22/func/sub-22_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-22/func/sub-22_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-22/func/sub-22_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-22/func/sub-22_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-22/func/sub-22_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-22/func/sub-22_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-22/func/sub-22_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-22/func/sub-22_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-22/func/sub-22_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-22/func/sub-22_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-22/func/sub-22_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-22/func/sub-22_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-22/func/sub-22_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-22/func/sub-22_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-23/func/sub-23_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-23/func/sub-23_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-23/func/sub-23_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-23/func/sub-23_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-23/func/sub-23_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-23/func/sub-23_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-23/func/sub-23_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-23/func/sub-23_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-23/func/sub-23_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-23/func/sub-23_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-23/func/sub-23_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-23/func/sub-23_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-23/func/sub-23_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-23/func/sub-23_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-23/func/sub-23_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-23/func/sub-23_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-23/func/sub-23_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-23/func/sub-23_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-23/func/sub-23_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-23/func/sub-23_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-24/func/sub-24_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-24/func/sub-24_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-24/func/sub-24_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-24/func/sub-24_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-24/func/sub-24_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-24/func/sub-24_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-24/func/sub-24_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-24/func/sub-24_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-24/func/sub-24_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-24/func/sub-24_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-24/func/sub-24_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-24/func/sub-24_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-24/func/sub-24_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-24/func/sub-24_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-24/func/sub-24_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-24/func/sub-24_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-24/func/sub-24_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-24/func/sub-24_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-24/func/sub-24_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-24/func/sub-24_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-25/func/sub-25_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-25/func/sub-25_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-25/func/sub-25_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-25/func/sub-25_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-25/func/sub-25_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-25/func/sub-25_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-25/func/sub-25_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-25/func/sub-25_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-25/func/sub-25_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-25/func/sub-25_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-25/func/sub-25_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-25/func/sub-25_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-25/func/sub-25_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-25/func/sub-25_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-25/func/sub-25_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-25/func/sub-25_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-25/func/sub-25_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-25/func/sub-25_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-25/func/sub-25_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-25/func/sub-25_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-26/func/sub-26_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-26/func/sub-26_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-26/func/sub-26_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-26/func/sub-26_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-26/func/sub-26_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-26/func/sub-26_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-26/func/sub-26_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-26/func/sub-26_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-26/func/sub-26_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-26/func/sub-26_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-26/func/sub-26_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-26/func/sub-26_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-26/func/sub-26_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-26/func/sub-26_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-26/func/sub-26_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-26/func/sub-26_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-26/func/sub-26_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-26/func/sub-26_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-26/func/sub-26_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-26/func/sub-26_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-27/func/sub-27_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-27/func/sub-27_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-27/func/sub-27_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-27/func/sub-27_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-27/func/sub-27_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-27/func/sub-27_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-27/func/sub-27_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-27/func/sub-27_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-27/func/sub-27_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-27/func/sub-27_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-27/func/sub-27_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-27/func/sub-27_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-27/func/sub-27_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-27/func/sub-27_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-27/func/sub-27_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-27/func/sub-27_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-27/func/sub-27_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-27/func/sub-27_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-27/func/sub-27_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-27/func/sub-27_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-28/func/sub-28_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-28/func/sub-28_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-28/func/sub-28_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-28/func/sub-28_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-28/func/sub-28_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-28/func/sub-28_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-28/func/sub-28_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-28/func/sub-28_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-28/func/sub-28_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-28/func/sub-28_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-28/func/sub-28_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-28/func/sub-28_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-28/func/sub-28_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-28/func/sub-28_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-28/func/sub-28_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-28/func/sub-28_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-28/func/sub-28_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-28/func/sub-28_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-28/func/sub-28_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-28/func/sub-28_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-29/func/sub-29_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-29/func/sub-29_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-29/func/sub-29_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-29/func/sub-29_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-29/func/sub-29_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-29/func/sub-29_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-29/func/sub-29_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-29/func/sub-29_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-29/func/sub-29_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-29/func/sub-29_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-29/func/sub-29_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-29/func/sub-29_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-29/func/sub-29_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-29/func/sub-29_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-29/func/sub-29_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-29/func/sub-29_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-29/func/sub-29_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-29/func/sub-29_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-29/func/sub-29_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-29/func/sub-29_task-teaching_run-10_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-30/func/sub-30_task-teaching_run-01_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-30/func/sub-30_task-teaching_run-01_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-30/func/sub-30_task-teaching_run-02_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-30/func/sub-30_task-teaching_run-02_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-30/func/sub-30_task-teaching_run-03_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-30/func/sub-30_task-teaching_run-03_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-30/func/sub-30_task-teaching_run-04_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-30/func/sub-30_task-teaching_run-04_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-30/func/sub-30_task-teaching_run-05_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-30/func/sub-30_task-teaching_run-05_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-30/func/sub-30_task-teaching_run-06_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-30/func/sub-30_task-teaching_run-06_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-30/func/sub-30_task-teaching_run-07_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-30/func/sub-30_task-teaching_run-07_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-30/func/sub-30_task-teaching_run-08_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-30/func/sub-30_task-teaching_run-08_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-30/func/sub-30_task-teaching_run-09_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-30/func/sub-30_task-teaching_run-09_model-empirical_events.tsv
#
# Loading file: ../../BIDS_data/sub-30/func/sub-30_task-teaching_run-10_events.tsv
# Saving to: ../../BIDS_data/derivatives/model_events/sub-30/func/sub-30_task-teaching_run-10_model-empirical_events.tsv
