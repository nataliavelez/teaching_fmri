# %% [markdown]
# # Exploratory: Save dataframes of all possible combos
# Natalia Vélez, April 2022

# %%
import os
import pandas as pd
import numpy as np
import teaching_models as teach
from os.path import join as opj

# %% [markdown]
# Generate all combinations of three examples

# %%
def example_combos(prob_idx):
    
    # start blank dataframe
    tuples = [(i, j, k) for i in range(36) for j in range(i+1, 36) for k in range(j+1, 36)]
    index = pd.MultiIndex.from_tuples(tuples, names=['ex_0', 'ex_1', 'ex_2'])
    prob_df = pd.DataFrame(np.zeros((len(index), 4), dtype=int), columns=['A', 'B', 'C', 'D'])
    prob_df.index = index

    # check if each hypothesis contains combos
    truth_table = teach.problem_df(prob_idx)    
    for idx, row in prob_df.iterrows():
        try:
            prob_df.loc[idx] = (truth_table.loc[list(idx)].sum() == 3)*1
        except KeyError: # skip missing indices
            pass
        
    # drop impossible combinations
    prob_df = prob_df.loc[(prob_df.sum(axis=1) > 0), :]
    
    return prob_df

# %% [markdown]
# Let's cache the combos for all problems:

# %%
out_dir = 'outputs/combos'
os.makedirs(out_dir, exist_ok=True)

for prob_idx in range(40):
    out_file = opj(out_dir, f'problem-{prob_idx:02}_combos.csv')
    prob_df = example_combos(prob_idx)
    
    prob_df.to_csv(out_file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-cb7e9f229ed3> in <module>
#       4 for prob_idx in range(40):
#       5     out_file = opj(out_dir, f'problem-{prob_idx:02}_combos.csv')
# ----> 6     prob_df = example_combos(prob_idx)
#       7
#       8     prob_df.to_csv(out_file)
#
# <ipython-input-68-1462e3b86b39> in example_combos(prob_idx)
#      13     # check if each hypothesis contains combos
#      14     for idx, row in prob_df.iterrows():
# ---> 15         prob_df.loc[idx] = (truth_table.loc[list(idx)].sum() == 3)*1
#      16
#      17     # drop impossible combinations
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1036         # A collection of keys
#    1037         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
# -> 1038         return self.obj._reindex_with_indexers(
#    1039             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1040         )
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4522
#    4523             # TODO: speed up on homogeneous DataFrame objects
# -> 4524             new_data = new_data.reindex_indexer(
#    4525                 index,
#    4526                 indexer,
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate)
#    1282             new_blocks = self._slice_take_blocks_ax0(indexer, fill_value=fill_value)
#    1283         else:
# -> 1284             new_blocks = [
#    1285                 blk.take_nd(
#    1286                     indexer,
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1283         else:
#    1284             new_blocks = [
# -> 1285                 blk.take_nd(
#    1286                     indexer,
#    1287                     axis=axis,
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1253             allow_fill = True
#    1254
# -> 1255         new_values = algos.take_nd(
#    1256             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1257         )
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1708             out = np.empty(out_shape, dtype=dtype)
#    1709
# -> 1710     func = _get_take_nd_function(
#    1711         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#    1712     )
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/algorithms.py in _get_take_nd_function(ndim, arr_dtype, out_dtype, axis, mask_info)
#    1489 ):
#    1490     if ndim <= 2:
# -> 1491         tup = (arr_dtype.name, out_dtype.name)
#    1492         if ndim == 1:
#    1493             func = _take_1d_dict.get(tup, None)
#
# ~/.local/lib/python3.8/site-packages/numpy/core/_dtype.py in _name_get(dtype)
#     340
#     341     # append bit counts
# --> 342     if _name_includes_bit_suffix(dtype):
#     343         name += "{}".format(dtype.itemsize * 8)
#     344
#
# ~/.local/lib/python3.8/site-packages/numpy/core/_dtype.py in _name_includes_bit_suffix(dtype)
#     316         # pointer size varies by system, best to omit it
#     317         return False
# --> 318     elif dtype.type == np.bool_:
#     319         # implied
#     320         return False
#
# KeyboardInterrupt:

# %%
example_combos(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-234aed428682> in <module>
# ----> 1 example_combos(2)
#
# <ipython-input-83-0f40a474068b> in example_combos(prob_idx)
#      10     truth_table = teach.problem_df(prob_idx)
#      11     for idx, row in prob_df.iterrows():
# ---> 12         prob_df.loc[idx] = (truth_table.loc[list(idx)].sum() == 3)*1
#      13
#      14     # drop impossible combinations
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1035
#    1036         # A collection of keys
# -> 1037         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1038         return self.obj._reindex_with_indexers(
#    1039             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /n/helmod/apps/centos7/Core/Anaconda3/2020.11-jupyterood-fasrc01/x/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1313
#    1314                 with option_context("display.max_seq_items", 10, "display.width", 80):
# -> 1315                     raise KeyError(
#    1316                         "Passing list-likes to .loc or [] with any missing labels "
#    1317                         "is no longer supported. "
#
# KeyError: "Passing list-likes to .loc or [] with any missing labels is no longer supported. The following labels were missing: Int64Index([5], dtype='int64', name='idx'). See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"

# %%
df = example_combos(2)
df
# Out:
#                 A  B  C  D
# ex_0 ex_1 ex_2
# 0    1    2     0  0  0  1
#           3     0  0  0  1
#           4     0  0  0  1
#           6     0  0  0  1
#           7     0  0  0  1
# ...            .. .. .. ..
# 24   27   28    0  0  0  1
# 25   26   27    0  1  0  1
#           28    0  1  0  1
#      27   28    0  1  0  1
# 26   27   28    0  1  0  1
#
# [2300 rows x 4 columns]

# %%
truth_table
# Out:
# hypothesis  A  B  C  D
# idx
# 0           0  0  0  1
# 1           1  0  0  1
# 2           1  0  0  1
# 3           1  0  0  1
# 4           1  0  0  1
# 5           0  0  0  1
# 6           0  0  0  1
# 7           1  0  0  1
# 8           1  0  0  1
# 9           1  0  0  1
# 10          1  0  0  1
# 11          0  0  0  1
# 12          0  0  0  1
# 13          1  0  0  1
# 14          1  0  0  1
# 15          1  0  0  1
# 16          1  0  0  1
# 17          0  0  0  1
# 18          0  0  1  1
# 19          1  1  1  1
# 20          1  1  1  1
# 21          1  1  1  1
# 22          1  1  1  1
# 23          0  1  0  1
# 24          0  0  1  0
# 25          1  1  1  0
# 26          1  1  1  0
# 27          1  1  1  0
# 28          1  1  1  0
# 29          0  1  0  0
# 30          0  0  1  0
# 31          1  1  1  0
# 32          1  1  1  0
# 33          1  1  1  0
# 34          1  1  1  0
# 35          0  1  0  0

# %%
df.loc[1]
# Out:
#            A  B  C  D
# ex_1 ex_2
# 2    6     0  1  0  0
#      7     0  1  0  0
#      8     0  1  0  0
#      12    0  1  0  0
#      13    0  1  0  0
#      14    0  1  0  0
#      15    0  1  0  0
#      20    0  1  0  0
#      21    0  1  0  0
# 6    7     0  1  0  0
#      8     0  1  0  0
#      12    0  1  0  0
#      13    0  1  0  0
#      14    0  1  0  0
#      15    0  1  0  0
#      20    0  1  0  0
#      21    0  1  0  0
# 7    8     0  1  0  0
#      12    0  1  0  0
#      13    0  1  0  0
#      14    0  1  0  0
#      15    0  1  0  0
#      20    0  1  0  0
#      21    0  1  0  0
# 8    12    0  1  0  0
#      13    0  1  0  0
#      14    0  1  0  0
#      15    0  1  0  0
#      20    0  1  0  0
#      21    0  1  0  0
# 12   13    0  1  0  0
#      14    0  1  0  0
#      15    0  1  0  0
#      20    0  1  0  0
#      21    0  1  0  0
# 13   14    0  1  0  0
#      15    0  1  0  0
#      20    0  1  0  0
#      21    0  1  0  0
# 14   15    0  1  0  0
#      20    0  1  0  0
#      21    0  1  0  0
# 15   20    0  1  0  0
#      21    0  1  0  0
# 20   21    0  1  0  0
